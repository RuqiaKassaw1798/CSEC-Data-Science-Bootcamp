# %% [markdown]
# <a href="https://colab.research.google.com/github/RuqiaKassaw1798/CSEC-Data-Science-Bootcamp/blob/main/my_own_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# My siblings dataset
My_siblings = {
    'Name': [
        'MohammedMekin', 'MohammedAsrar', 'MohammedAmmin', 'Ahmedlahadi', 'Abdellah',
        'Nureddin', 'Seadiya', 'Haykel', 'Fethya', 'Ammar',
        'Shikur', 'Hasinet', 'Abubekr', 'Sumeya', 'Hidaya'
    ],
    'Relation': [
        'Brother', 'Brother', 'Brother', 'Brother', 'Brother',
        'Brother', 'Sister', 'Sister', 'Sister', 'Brother',
        'Brother', 'Sister', 'Brother', 'Sister', 'Sister'
    ],
    'Age': [27, 26, 24, 24, 22, 20, 17, 17, 14, 13, 11, 8, 4, 5, 2],
    'Education_Level': [
        'Graduated', 'University', 'University', 'Employed', 'Religious Education',
        'Religious Education', '12th grade', '11th grade', '8th grade', 'Religious Education',
        '5th grade', '2nd grade', 'Pre-school age', 'Pre-school age', 'Toddler'
    ],
    'Hobby': [
        'Family man', 'Drawing', 'Politics', 'Driving', 'Soccer',
        'Reading', 'Reading', 'Cooking', 'Tech', 'Reading',
        'Playing', 'Playing', 'Playing', 'Playing', 'Playing'
    ]
}

# Assigning custom index (SIB_01 to SIB_15)
customIndex = [f'SIB_{i:02d}' for i in range(1, 16)]

# Building the DataFrame
My_siblings = pd.DataFrame(My_siblings, index=customIndex)

# Display the final dataset
My_siblings
# Out:
#                  Name Relation  Age      Education_Level       Hobby
# SIB_01  MohammedMekin  Brother   27            Graduated  Family man
# SIB_02  MohammedAsrar  Brother   26           University     Drawing
# SIB_03  MohammedAmmin  Brother   24           University    Politics
# SIB_04    Ahmedlahadi  Brother   24             Employed     Driving
# SIB_05       Abdellah  Brother   22  Religious Education      Soccer
# SIB_06       Nureddin  Brother   20  Religious Education     Reading
# SIB_07        Seadiya   Sister   17           12th grade     Reading
# SIB_08         Haykel   Sister   17           11th grade     Cooking
# SIB_09         Fethya   Sister   14            8th grade        Tech
# SIB_10          Ammar  Brother   13  Religious Education     Reading
# SIB_11         Shikur  Brother   11            5th grade     Playing
# SIB_12        Hasinet   Sister    8            2nd grade     Playing
# SIB_13        Abubekr  Brother    4       Pre-school age     Playing
# ...
